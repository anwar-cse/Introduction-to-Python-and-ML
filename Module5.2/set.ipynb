# %% [markdown]
# set

# %%
s={1,2,3,4,4,5,5} #Duplicate remove

#list=[1,2,3,4,4,5,5]
#s=set(list)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# methods

# %%
s.add(7)
print(s)
s.remove(7)
print(s)
s.pop() #random element remove
print(s)
# Out:
# {1, 2, 3, 4, 5, 7}
# {1, 2, 3, 4, 5}
# {2, 3, 4, 5}

# %% [markdown]
# set operations

# %%
#union
a={1,2,3}
b={3,4,5}
print(a|b)
#intersection
print(a&b)
#difference
print(a-b)
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
