# %%
#variable declare
name="Anwar"
age=45
cgpa=3.76
bool=True
print(name,age)

#data type
print(type(name),type(age),type(cgpa),type(bool))
# Out:
# Anwar 45
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>
