# %% [markdown]
# Min_Max:
# https://codeforces.com/group/MWSDmqGsZm/contest/219158/problem/K

# %%
inp=input()
num=inp.split()
a=int(num[0])
b=int(num[1])
c=int(num[2])

min=a
max=a

if(b<min):
    min=b
if(c<min):
    min=c
    
if(b>max):
    max=b
if(c>max):
    max=c
print(min, max)
# Out:
# -3 -1
