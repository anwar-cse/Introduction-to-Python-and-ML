# %% [markdown]
# tuples

# %%
#Indexing
t=(9,2,3,1,5)
print(t[0],t[-1])

#slicing
print(t[1:3])
# Out:
# 9 5
# (2, 3)

# %% [markdown]
# methods

# %%
#index
print(t.index(5))

#count
print(t.count(5))
# Out:
# 4
# 1
