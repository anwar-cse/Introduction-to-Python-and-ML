# %% [markdown]
# conditional statement

# %%
taka = int(input("enter the amount of course fee: "))

if taka == 7500:
    print("enroll in machine learning of phitron")
elif taka > 7500:
    print(f"extra payable taka = {taka - 7500}")
else:
    print(f"need taka = {7500 - taka}")
# Out:
# need taka = 6750
